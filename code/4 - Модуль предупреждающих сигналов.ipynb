# %% [markdown]
# ## 4 - Модуль предупреждающих сигналов

# %% [markdown]
# ### 4.1 - Библиотеки

# %%
import pandas as pd
import numpy as np

from _utils.text_preporation import master_scale
from _utils.qualitative_features_analysis import comprehensive_feature_analysis, recommend_features_to_drop

import yaml

import warnings
warnings.filterwarnings("ignore")

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### 4.2 - Пути

# %%
with open('../CONFIGS.yaml', 'r') as file:
    CONFIG = yaml.safe_load(file)

PATHS = CONFIG['data_paths']

# %%
filepath = {
      'warnings_processed' : PATHS['module_warnings']['processed_data']
    , 'warnings_raw'       : PATHS['module_warnings']['raw_data']
    , 'rating_weights'     : PATHS['ratings']['weights']
    , 'youngs_data'        : PATHS['case_youngs']['processed_data']
    , 'master_scale'       : PATHS['ratings']['master_scale']
    , 'final_signals'      : PATHS['module_warnings']['final']
}

# %%
target_col = 'target'
weight_col = 'W_norm'

id_cols = ['client_id', 'rating_id', target_col, weight_col]

EXCLUDE_SIGNALS = False

# %% [markdown]
# ### 4.3 - Чтение файлов

# %%
df = pd.read_parquet(filepath['warnings_processed'])
df_warnings = pd.read_excel(filepath['warnings_raw'])
warnings_names = df_warnings.copy()
warnings_names = warnings_names[['Показатель', 'Код интеграции']].set_axis(['definition', 'code'], axis=1)

df_weights = pd.read_parquet(filepath['rating_weights'])
df_dpd = pd.read_parquet(PATHS['risk']['dpd_data'])

master = pd.read_excel(filepath['master_scale'])
master.rename(columns = {
      'Рейтинг' : 'rating'
    , 'Нижний предел' : 'lower_bound'
    , 'Вероятность Дефолта' : 'pd'
    , 'Верхний предел' : 'upper_bound'
}, inplace=True)

# %% [markdown]
# ### 4.4 - Формирование датасета

# %%
df_warnings = df_warnings.rename(columns = {  'Код интеграции': 'signal'
                                            , 'Ухудшение рейтинга': 'current_rating'})
df_warnings = df_warnings[['signal', 'current_rating']]
df_warnings['signal_type']  = np.where(df_warnings['current_rating'] < 17, 'additive', 'target')

# %%
df_warnings.signal_type.value_counts(dropna=False)
# Out:
# signal_type
# target      32
# additive    10
# Name: count, dtype: int64

# %%
df_signals = pd.merge(df,
                      df_weights,
                      on=['client_id', 'rating_id'],
                      how='inner')

df_signals = pd.merge(df_signals,
                      df_dpd,
                      on=['rating_id'],
                      how='inner')

df_signals.head(3)
# Out:
#    client_id  rating_id kws1 kws2 kws3 kws4 kws5 kws7 kws8 kws9 kws10 kws11  \
# 0     176783       1737  Нет  Нет  Нет  Нет  Нет  Нет  Нет  Нет   Нет   Нет
# 1     197185       1048  Нет  Нет  Нет  Нет  Нет  Нет  Нет  Нет   Нет   Нет
# 2     197255        912  Нет  Нет  Нет  Нет  Нет  Нет  Нет  Нет   Нет   Нет
#
#   kws12 kws14 kws17 kws18 DT0800 kws26 kws27 kws25 DT0100 DT0200 DT0400  \
# 0   Нет   Нет   Нет   Нет    Нет   Нет   Нет   Нет    Нет    Нет    Нет
# 1   Нет   Нет   Нет   Нет    Нет   Нет   Нет   Нет    Нет    Нет    Нет
# 2   Нет   Нет   Нет   Нет    Нет   Нет   Нет   Нет    Нет    Нет    Нет
#
#   DT0500 DT0600 DT0700 DT0700_1 DT0700_2 DT0700_3 DT0700_4 DT0700_5 DT0700_6  \
# 0    Нет    Нет    Нет      Нет      Нет      Нет      Нет      Нет      Нет
# 1    Нет    Нет    Нет      Нет      Нет      Нет      Нет      Нет      Нет
# 2    Нет    Нет    Нет      Нет      Нет      Нет      Нет      Нет      Нет
#
#   DT0700_7 DT0700_8 DT0700_9 DT0700_10 DT0900 DT1000 rating_assignment_date  \
# 0      Нет      Нет      Нет       Нет    Нет    Нет             2018-12-12
# 1      Нет      Нет      Нет       Нет    Нет    Нет             2018-08-14
# 2      Нет      Нет      Нет       Нет    Нет    Нет             2018-07-30
#
#    target valid_date  weight_day  weight_1  weight_2         W  \
# 0       0 2019-12-12    0.003344  2.920920   1.30492  3.219233
# 1       0 2019-08-14    0.010526  3.503319   1.30492  3.861112
# 2       0 2018-12-19    0.015873  2.381363   1.30492  2.624572
#
#    weight_day_norm  weight_1_norm  weight_2_norm    W_norm  dpd
# 0         0.000296       0.590623        1.30492  2.843321    0
# 1         0.000931       0.491416        1.30492  2.365725    0
# 2         0.001404       0.210654        1.30492  1.014112    0

# %% [markdown]
# ### 4.5 - Определение предсигналов

# %% [markdown]
# #### 4.5.1 - Обработака основных предсигналов

# %%
warnings_cols = [col for col in df_signals.columns if 'kws' in col or 'DT' in col]
warnings_cols
# Out:
# ['kws1',
#  'kws2',
#  'kws3',
#  'kws4',
#  'kws5',
#  'kws7',
#  'kws8',
#  'kws9',
#  'kws10',
#  'kws11',
#  'kws12',
#  'kws14',
#  'kws17',
#  'kws18',
#  'DT0800',
#  'kws26',
#  'kws27',
#  'kws25',
#  'DT0100',
#  'DT0200',
#  'DT0400',
#  'DT0500',
#  'DT0600',
#  'DT0700',
#  'DT0700_1',
#  'DT0700_2',
#  'DT0700_3',
#  'DT0700_4',
#  'DT0700_5',
#  'DT0700_6',
#  'DT0700_7',
#  'DT0700_8',
#  'DT0700_9',
#  'DT0700_10',
#  'DT0900',
#  'DT1000']

# %%
df_signals = df_signals[id_cols + warnings_cols + ['dpd']].copy()

# %%
for column in warnings_cols:
    df_signals[column] = df_signals[column].fillna('0')
    df_signals[column] = df_signals[column].apply(lambda x: str(x).lower().strip())
    df_signals[column] = df_signals[column].replace('да','1')
    df_signals[column] = df_signals[column].replace('нет','0')
    df_signals[column] = df_signals[column].astype(int)

# %% [markdown]
# #### 4.5.2 - Новые предсигналы по просрочке

# %%
df_signals['5_15_dpd'] = np.where((df_signals['dpd'] >= 5) & (df_signals['dpd'] <= 15), 1, 0)
df_signals['16_29_dpd'] = np.where((df_signals['dpd'] >= 16) & (df_signals['dpd'] <= 29), 1, 0)

warnings_cols += ['5_15_dpd', '16_29_dpd']

# %% [markdown]
# ### 4.6 - Анализ предсигналов

# %% [markdown]
# #### 4.6.1 - Подсчет метрик вариативности

# %%
# Анализируем
signals_analysis = comprehensive_feature_analysis(
    df=df_signals,
    features=warnings_cols,
    target_col=target_col,
    verbose=False
)

signals_analysis = signals_analysis.merge(warnings_names, left_on='feature', right_on='code', how='left')

# %% [markdown]
# #### 4.6.2 - Определение незначимых по метрикам пред. сигналов

# %%
signals_constants = signals_analysis.query('unique_values<=1').feature.values.tolist()
signals_with_no_def_spread = signals_analysis.query('default_rate_spread == 0 ')['feature'].values
signals_with_no_IV = signals_analysis.query('information_value == 0 ')['feature'].values
excluded_signals = set(signals_constants)\
                    .intersection(set(signals_with_no_def_spread))\
                    .intersection(set(signals_with_no_IV))
print(f'Сигналы на рассмотрение на исключение ({len(excluded_signals)} штук из {len(warnings_cols)})')
print(list(excluded_signals))
# Out:
# Сигналы на рассмотрение на исключение (22 штук из 38)
# ['DT1000', 'DT0700_10', 'DT0700_2', 'DT0700_9', 'DT0700_5', 'DT0700_3', 'DT0400', 'DT0700_1', 'kws11', 'DT0700_4', 'kws5', 'DT0700', 'DT0700_8', 'DT0200', 'DT0100', 'DT0500', 'kws7', 'kws25', 'DT0700_7', 'DT0900', 'DT0800', 'DT0700_6']

# %% [markdown]
# #### 4.6.3 - Выбор полного или сокращенного набора пред. сигналов

# %%
selected_signals = warnings_cols
if EXCLUDE_SIGNALS:
    selected_signals = [f for f in warnings_cols if f not in excluded_signals]
    
print(len(selected_signals), '/', len(warnings_cols))
# Out:
# 38 / 38

# %%
if EXCLUDE_SIGNALS:
    display(signals_analysis.query('feature in @selected_signals')[['feature','unique_values', 'information_value', 'default_rate_spread', 'definition']])

# %% [markdown]
# ### 4.7 - Анализ текущих и переподсчитанных рейтингов для каждого сигнала на основании срабатываний и дефолтов на текущих анализируемых данных

# %% [markdown]
# #### 4.7.1 - Подсчет

# %%
w = pd.DataFrame()

columns = warnings_cols

signal_triggered_count = []
total_observations = []
defaults_when_triggered = []
total_weight_triggered = []
default_weight_triggered = []
for i in columns:
    signal_triggered_count.append(df_signals[df_signals[i] == 1].shape[0])
    total_observations.append(df_signals.shape[0])
    defaults_when_triggered.append(df_signals[df_signals[i] == 1][target_col].sum())
    total_weight_triggered.append(df_signals[df_signals[i] == 1][weight_col].sum())
    default_weight_triggered.append(df_signals[(df_signals[i] == 1) & (df_signals[target_col] == 1)][weight_col].sum())
    
    
w['signal'] = columns
w['total_observations'] = total_observations
w['signal_triggered_count'] = signal_triggered_count
w['defaults_when_triggered'] = defaults_when_triggered
w['total_weight_triggered'] = total_weight_triggered
w['default_weight_triggered'] = default_weight_triggered

w = pd.merge(w,
             df_warnings,
             how = 'left',
             on = ['signal'])


#  Невзвешанный рейтинг
w['triggered_dr'] = w['defaults_when_triggered'] / w['signal_triggered_count']
w.fillna({'triggered_dr' : 0}, inplace=True)
w['unweighted_rating'] = w['triggered_dr'].apply(lambda x: master_scale(x, master))

# Взвешанный рейтинг
w['triggered_weighted_dr'] = w['default_weight_triggered'] / w['total_weight_triggered']
w.fillna({'triggered_weighted_dr' : 0}, inplace=True)
w['weighted_rating'] = w['triggered_weighted_dr'].apply(lambda x: master_scale(x,master))

w.fillna({'signal_type' : 'target'}, inplace=True)

# Доп. метрика
w['coverage'] = w['defaults_when_triggered'] / df_signals[target_col].sum()  # Покрытие (% от всех дефолтов)

# Сортировка для наглядности
w = w.sort_values(['coverage', 'current_rating', 'unweighted_rating', 'weighted_rating'], ascending=False)
w = w.merge(warnings_names, left_on='signal', right_on='code', how='left').drop('code', axis=1)
w
# Out:
#        signal  total_observations  signal_triggered_count  \
# 0       kws14                4984                      31
# 1    5_15_dpd                4984                      82
# 2   16_29_dpd                4984                      22
# 3        kws1                4984                      11
# 4        kws9                4984                      23
# 5        kws4                4984                      30
# 6       kws17                4984                      66
# 7        kws3                4984                       3
# 8       kws18                4984                       6
# 9      DT0600                4984                       1
# 10      kws27                4984                       1
# 11      kws26                4984                       7
# 12      kws12                4984                       9
# 13     DT0800                4984                       0
# 14      kws25                4984                       0
# 15     DT0100                4984                       0
# 16     DT0200                4984                       0
# 17     DT0400                4984                       0
# 18     DT0500                4984                       0
# 19     DT0700                4984                       0
# 20   DT0700_1                4984                       0
# 21   DT0700_2                4984                       0
# 22   DT0700_3                4984                       0
# 23   DT0700_4                4984                       0
# 24   DT0700_5                4984                       0
# 25   DT0700_6                4984                       0
# 26   DT0700_7                4984                       0
# 27   DT0700_8                4984                       0
# 28   DT0700_9                4984                       0
# 29  DT0700_10                4984                       0
# 30     DT0900                4984                       0
# 31     DT1000                4984                       0
# 32      kws10                4984                       3
# 33       kws5                4984                       0
# 34       kws8                4984                       3
# 35       kws7                4984                       0
# 36      kws11                4984                       0
# 37       kws2                4984                       9
#
#     defaults_when_triggered  total_weight_triggered  default_weight_triggered  \
# 0                        24               28.998697                 20.654883
# 1                        23               50.229038                 10.357334
# 2                        15               15.748830                 11.000120
# 3                         8                9.416465                  7.259177
# 4                         4               23.938444                  2.948196
# 5                         4               35.133426                  5.494774
# 6                         4               59.075191                  4.922502
# 7                         3                1.598020                  1.598020
# 8                         2                4.662187                  1.366822
# 9                         1                1.120919                  1.120919
# 10                        1                1.803688                  1.803688
# 11                        1                8.863565                  1.803688
# 12                        1                6.948239                  0.094990
# 13                        0                0.000000                  0.000000
# 14                        0                0.000000                  0.000000
# 15                        0                0.000000                  0.000000
# 16                        0                0.000000                  0.000000
# 17                        0                0.000000                  0.000000
# 18                        0                0.000000                  0.000000
# 19                        0                0.000000                  0.000000
# 20                        0                0.000000                  0.000000
# 21                        0                0.000000                  0.000000
# 22                        0                0.000000                  0.000000
# 23                        0                0.000000                  0.000000
# 24                        0                0.000000                  0.000000
# 25                        0                0.000000                  0.000000
# 26                        0                0.000000                  0.000000
# 27                        0                0.000000                  0.000000
# 28                        0                0.000000                  0.000000
# 29                        0                0.000000                  0.000000
# 30                        0                0.000000                  0.000000
# 31                        0                0.000000                  0.000000
# 32                        0                6.706056                  0.000000
# 33                        0                0.000000                  0.000000
# 34                        0                3.102761                  0.000000
# 35                        0                0.000000                  0.000000
# 36                        0                0.000000                  0.000000
# 37                        0               11.243035                  0.000000
#
#     current_rating signal_type  triggered_dr  unweighted_rating  \
# 0               25      target      0.774194               25.0
# 1               23      target      0.280488               23.0
# 2               25      target      0.681818               25.0
# 3                2    additive      0.727273               25.0
# 4               23      target      0.173913               21.0
# 5                3    additive      0.133333               20.0
# 6                2    additive      0.060606               18.0
# 7                2    additive      1.000000               26.0
# 8               24      target      0.333333               23.0
# 9               26      target      1.000000               26.0
# 10              19      target      1.000000               26.0
# 11              17      target      0.142857               21.0
# 12               5    additive      0.111111               20.0
# 13              26      target      0.000000                NaN
# 14              26      target      0.000000                NaN
# 15              26      target      0.000000                NaN
# 16              26      target      0.000000                NaN
# 17              26      target      0.000000                NaN
# 18              26      target      0.000000                NaN
# 19              26      target      0.000000                NaN
# 20              26      target      0.000000                NaN
# 21              26      target      0.000000                NaN
# 22              26      target      0.000000                NaN
# 23              26      target      0.000000                NaN
# 24              26      target      0.000000                NaN
# 25              26      target      0.000000                NaN
# 26              26      target      0.000000                NaN
# 27              26      target      0.000000                NaN
# 28              26      target      0.000000                NaN
# 29              26      target      0.000000                NaN
# 30              26      target      0.000000                NaN
# 31              26      target      0.000000                NaN
# 32              25      target      0.000000                NaN
# 33               8    additive      0.000000                NaN
# 34               8    additive      0.000000                NaN
# 35               5    additive      0.000000                NaN
# 36               5    additive      0.000000                NaN
# 37               2    additive      0.000000                NaN
#
#     triggered_weighted_dr  weighted_rating  coverage  \
# 0                0.712269             25.0  0.096386
# 1                0.206202             22.0  0.092369
# 2                0.698472             25.0  0.060241
# 3                0.770903             25.0  0.032129
# 4                0.123157             20.0  0.016064
# 5                0.156397             21.0  0.016064
# 6                0.083326             19.0  0.016064
# 7                1.000000             26.0  0.012048
# 8                0.293172             23.0  0.008032
# 9                1.000000             26.0  0.004016
# 10               1.000000             26.0  0.004016
# 11               0.203495             22.0  0.004016
# 12               0.013671             13.0  0.004016
# 13               0.000000              NaN  0.000000
# 14               0.000000              NaN  0.000000
# 15               0.000000              NaN  0.000000
# 16               0.000000              NaN  0.000000
# 17               0.000000              NaN  0.000000
# 18               0.000000              NaN  0.000000
# 19               0.000000              NaN  0.000000
# 20               0.000000              NaN  0.000000
# 21               0.000000              NaN  0.000000
# 22               0.000000              NaN  0.000000
# 23               0.000000              NaN  0.000000
# 24               0.000000              NaN  0.000000
# 25               0.000000              NaN  0.000000
# 26               0.000000              NaN  0.000000
# 27               0.000000              NaN  0.000000
# 28               0.000000              NaN  0.000000
# 29               0.000000              NaN  0.000000
# 30               0.000000              NaN  0.000000
# 31               0.000000              NaN  0.000000
# 32               0.000000              NaN  0.000000
# 33               0.000000              NaN  0.000000
# 34               0.000000              NaN  0.000000
# 35               0.000000              NaN  0.000000
# 36               0.000000              NaN  0.000000
# 37               0.000000              NaN  0.000000
#
#                                            definition
# 0   Просрочка платежа от 30 до 60 календарных дней...
# 1   Просрочка платежа от 5 до 16 календарных дней ...
# 2   Просрочка платежа от 16 до 30 календарных дней...
# 3   Наложение кредиторами ареста на расчетные счет...
# 4   Существенное нарушение условий кредитной докум...
# 5   Наличие негативной информации о деловой репута...
# 6   Наличие просрочек по налоговым выплатам, несущ...
# 7   Нестабильное поведение уполномоченных представ...
# 8   Наличие просрочек по налоговым выплатам, сущес...
# 9   Реструктуризация: реструктуризация обязательст...
# 10  Отсутствие выручки более, чем за одну отчетную...
# 11  Отсутствие выручки за одну отчетную дату из пя...
# 12  Существенное ухудшение финансового положения и...
# 13  Дефолт на финансовых рынках: вероятное неиспол...
# 14  Наличие просроченной задолженности непрерывной...
# 15  NPL 90+: корпоративный заемщик просрочил выпла...
# 16  Банкротство: Банк инициировал начало судебного...
# 17  Принудительное взыскание: Банк инициировал про...
# 18  Ликвидация: принятие корпоративным заемщиком/К...
# 19  Ожидаемая неплатежеспособность: вероятное непо...
# 20  Отказ Заемщика от погашения Задолженности, выр...
# 21  По результатам проверки ГСЗ выявлено отрицател...
# 22  Принятие Кредитующим подразделением и ПРПА сов...
# 23             Отсутствие любых источников погашения.
# 24  Наличие производства по делу о несостоятельнос...
# 25  Принятие Коллегиальным органом Банка решения о...
# 26         Причастность к экстремисткой деятельности.
# 27  Обращение Заемщика с предложением о принятии и...
# 28              Присвоена "Черная зона проблемности".
# 29  Инициирование Банком возбуждения уголовных дел...
# 30  Списание: принято решение уполномоченным колле...
# 31  Уступка: уступка прав требования по обязательс...
# 32  Имеются доказательства мошенничества, по инфор...
# 33  Информация о возможном мошенничестве (в частно...
# 34  Внесение изменений в учредительные документы к...
# 35  Информация о действиях владельцев / уполномоче...
# 36  Существенное нарушение основных операций контр...
# 37  Изменения в составе собственников и / или мене...

# %% [markdown]
# #### 4.7.2 - Сравнение

# %%
w[w['current_rating'] < w[['unweighted_rating','weighted_rating']].max(axis=1)]\
    .query('signal in @selected_signals')
# Out:
#    signal  total_observations  signal_triggered_count  \
# 3    kws1                4984                      11
# 5    kws4                4984                      30
# 6   kws17                4984                      66
# 7    kws3                4984                       3
# 10  kws27                4984                       1
# 11  kws26                4984                       7
# 12  kws12                4984                       9
#
#     defaults_when_triggered  total_weight_triggered  default_weight_triggered  \
# 3                         8                9.416465                  7.259177
# 5                         4               35.133426                  5.494774
# 6                         4               59.075191                  4.922502
# 7                         3                1.598020                  1.598020
# 10                        1                1.803688                  1.803688
# 11                        1                8.863565                  1.803688
# 12                        1                6.948239                  0.094990
#
#     current_rating signal_type  triggered_dr  unweighted_rating  \
# 3                2    additive      0.727273               25.0
# 5                3    additive      0.133333               20.0
# 6                2    additive      0.060606               18.0
# 7                2    additive      1.000000               26.0
# 10              19      target      1.000000               26.0
# 11              17      target      0.142857               21.0
# 12               5    additive      0.111111               20.0
#
#     triggered_weighted_dr  weighted_rating  coverage  \
# 3                0.770903             25.0  0.032129
# 5                0.156397             21.0  0.016064
# 6                0.083326             19.0  0.016064
# 7                1.000000             26.0  0.012048
# 10               1.000000             26.0  0.004016
# 11               0.203495             22.0  0.004016
# 12               0.013671             13.0  0.004016
#
#                                            definition
# 3   Наложение кредиторами ареста на расчетные счет...
# 5   Наличие негативной информации о деловой репута...
# 6   Наличие просрочек по налоговым выплатам, несущ...
# 7   Нестабильное поведение уполномоченных представ...
# 10  Отсутствие выручки более, чем за одну отчетную...
# 11  Отсутствие выручки за одну отчетную дату из пя...
# 12  Существенное ухудшение финансового положения и...

# %%
w.query('signal in @selected_signals').query('signal_type == "target" and current_rating != 26')
# Out:
#        signal  total_observations  signal_triggered_count  \
# 0       kws14                4984                      31
# 1    5_15_dpd                4984                      82
# 2   16_29_dpd                4984                      22
# 4        kws9                4984                      23
# 8       kws18                4984                       6
# 10      kws27                4984                       1
# 11      kws26                4984                       7
# 32      kws10                4984                       3
#
#     defaults_when_triggered  total_weight_triggered  default_weight_triggered  \
# 0                        24               28.998697                 20.654883
# 1                        23               50.229038                 10.357334
# 2                        15               15.748830                 11.000120
# 4                         4               23.938444                  2.948196
# 8                         2                4.662187                  1.366822
# 10                        1                1.803688                  1.803688
# 11                        1                8.863565                  1.803688
# 32                        0                6.706056                  0.000000
#
#     current_rating signal_type  triggered_dr  unweighted_rating  \
# 0               25      target      0.774194               25.0
# 1               23      target      0.280488               23.0
# 2               25      target      0.681818               25.0
# 4               23      target      0.173913               21.0
# 8               24      target      0.333333               23.0
# 10              19      target      1.000000               26.0
# 11              17      target      0.142857               21.0
# 32              25      target      0.000000                NaN
#
#     triggered_weighted_dr  weighted_rating  coverage  \
# 0                0.712269             25.0  0.096386
# 1                0.206202             22.0  0.092369
# 2                0.698472             25.0  0.060241
# 4                0.123157             20.0  0.016064
# 8                0.293172             23.0  0.008032
# 10               1.000000             26.0  0.004016
# 11               0.203495             22.0  0.004016
# 32               0.000000              NaN  0.000000
#
#                                            definition
# 0   Просрочка платежа от 30 до 60 календарных дней...
# 1   Просрочка платежа от 5 до 16 календарных дней ...
# 2   Просрочка платежа от 16 до 30 календарных дней...
# 4   Существенное нарушение условий кредитной докум...
# 8   Наличие просрочек по налоговым выплатам, сущес...
# 10  Отсутствие выручки более, чем за одну отчетную...
# 11  Отсутствие выручки за одну отчетную дату из пя...
# 32  Имеются доказательства мошенничества, по инфор...

# %% [markdown]
# ## 4.8 - Финальные предсигналы

# %%
warnings_cols_to_drop = ['kws13', 'kws15', 'DT0300', 'DT1100', 'DT0100']
selected_signals      = [s for s in selected_signals if s not in warnings_cols_to_drop]
selected_signals      =    [col for col in selected_signals if 'kws' in col] \
                         + [col for col in selected_signals if 'dpd' in col] \
                         + [col for col in selected_signals if 'DT'  in col] 
selected_signals
# Out:
# ['kws1',
#  'kws2',
#  'kws3',
#  'kws4',
#  'kws5',
#  'kws7',
#  'kws8',
#  'kws9',
#  'kws10',
#  'kws11',
#  'kws12',
#  'kws14',
#  'kws17',
#  'kws18',
#  'kws26',
#  'kws27',
#  'kws25',
#  '5_15_dpd',
#  '16_29_dpd',
#  'DT0800',
#  'DT0200',
#  'DT0400',
#  'DT0500',
#  'DT0600',
#  'DT0700',
#  'DT0700_1',
#  'DT0700_2',
#  'DT0700_3',
#  'DT0700_4',
#  'DT0700_5',
#  'DT0700_6',
#  'DT0700_7',
#  'DT0700_8',
#  'DT0700_9',
#  'DT0700_10',
#  'DT0900',
#  'DT1000']

# %% [markdown]
# ## 4.9 - Сохранение предсигналов

# %%
print(len(selected_signals),'/', len(warnings_cols))
# Out:
# 37 / 38

# %%
df_signals = df_signals[['client_id', 'rating_id'] + selected_signals]

# %%
df_signals.to_parquet(filepath['final_signals'])
